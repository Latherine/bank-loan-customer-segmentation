# %%
import pandas as pd

# %%
#read cvs
df = pd.read_csv('C:\Users\ACER\Downloads\financial_loan.csv')
df.head()
# Out:
#   Cell In[5], line 2
#     df = pd.read_csv('C:\Users\ACER\Downloads\financial_loan.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
